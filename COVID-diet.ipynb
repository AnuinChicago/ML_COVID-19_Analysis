# %% [markdown]
# # "Can you predict COVID deaths by food habits?"

# %%
# Dependencies
import pandas as pd

import numpy as np
from matplotlib import pyplot as plt

import requests

# %% [markdown]
# # Objective
# ### We want to analyse the data to see if healthy diet plays a factor in low death rate due to COVID-19

# %%
# File Path
diet_data_file = "datasets_618335_1395643_Food_Supply_Quantity_kg_Data.csv"

# Read CSV
diet_data = pd.read_csv(diet_data_file)

# Show Data
diet_data
# Out:
#                  Country  Alcoholic Beverages  Animal fats  Animal Products  \
# 0            Afghanistan               0.0014       0.1973           9.4341
# 1                Albania               1.6719       0.1357          18.7684
# 2                Algeria               0.2711       0.0282           9.6334
# 3                 Angola               5.8087       0.0560           4.9278
# 4    Antigua and Barbuda               3.5764       0.0087          16.6613
# ..                   ...                  ...          ...              ...
# 165            Venezuela               2.5952       0.0403          14.7565
# 166              Vietnam               1.4591       0.1640           8.5765
# 167                Yemen               0.0364       0.0446           5.7874
# 168               Zambia               5.7360       0.0829           6.0197
# 169             Zimbabwe               4.0552       0.0755           8.1489
#
#      Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                     0.0000                   24.8097  0.2099         0.0350
# 1                     0.0000                    5.7817  0.5815         0.2126
# 2                     0.0000                   13.6816  0.5277         0.2416
# 3                     0.0000                    9.1085  0.0587         1.7707
# 4                     0.0000                    5.9960  0.2274         4.1489
# ..                       ...                       ...     ...            ...
# 165                   0.0000                   12.9253  0.3389         0.9456
# 166                   0.0042                   16.8740  0.3077         2.6392
# 167                   0.0000                   27.2077  0.2579         0.5240
# 168                   0.0000                   21.1938  0.3399         1.6924
# 169                   0.0000                   22.6240  0.2678         0.5518
#
#      Fruits - Excluding Wine    Meat  ...  Vegetables  Vegetal Products  \
# 0                     5.3495  1.2020  ...      6.7642           40.5645
# 1                     6.7861  1.8845  ...     11.7753           31.2304
# 2                     6.3801  1.1305  ...     11.6484           40.3651
# 3                     6.0005  2.0571  ...      2.3041           45.0722
# 4                    10.7451  5.6888  ...      5.4495           33.3233
# ..                       ...     ...  ...         ...               ...
# 165                   7.6460  3.8328  ...      4.1474           35.2416
# 166                   5.9029  4.4382  ...     11.9508           41.4232
# 167                   5.1344  2.7871  ...      3.2135           44.2126
# 168                   1.0183  1.8427  ...      3.4649           43.9789
# 169                   2.2000  2.6142  ...      2.3213           41.8526
#
#      Obesity  Undernourished  Confirmed    Deaths  Recovered    Active  \
# 0        4.5            29.8   0.094302  0.003298   0.065531  0.025473
# 1       22.3             6.2   0.194468  0.005849   0.106342  0.082276
# 2       26.6             3.9   0.070936  0.002775   0.048288  0.019873
# 3        6.8              25   0.003687  0.000169   0.001418  0.002100
# 4       19.1             NaN   0.092857  0.003061   0.068367  0.021429
# ..       ...             ...        ...       ...        ...       ...
# 165     25.2            21.2   0.070539  0.000607   0.039811  0.030120
# 166      2.1             9.3   0.000645  0.000006   0.000388  0.000252
# 167     14.1            38.9   0.005814  0.001666   0.002890  0.001257
# 168      6.5            46.7   0.034525  0.000925   0.024440  0.009160
# 169     12.3            51.3   0.026381  0.000471   0.006836  0.019074
#
#      Population  Unit (all except Population)
# 0    38928000.0                             %
# 1     2838000.0                             %
# 2    44357000.0                             %
# 3    32522000.0                             %
# 4       98000.0                             %
# ..          ...                           ...
# 165  28645000.0                             %
# 166  96209000.0                             %
# 167  29826000.0                             %
# 168  18384000.0                             %
# 169  14863000.0                             %
#
# [170 rows x 32 columns]

# %%
list(diet_data.columns)
# Out:
# ['Country',
#  'Alcoholic Beverages',
#  'Animal fats',
#  'Animal Products',
#  'Aquatic Products, Other',
#  'Cereals - Excluding Beer',
#  'Eggs',
#  'Fish, Seafood',
#  'Fruits - Excluding Wine',
#  'Meat',
#  'Milk - Excluding Butter',
#  'Miscellaneous',
#  'Offals',
#  'Oilcrops',
#  'Pulses',
#  'Spices',
#  'Starchy Roots',
#  'Stimulants',
#  'Sugar & Sweeteners',
#  'Sugar Crops',
#  'Treenuts',
#  'Vegetable Oils',
#  'Vegetables',
#  'Vegetal Products',
#  'Obesity',
#  'Undernourished',
#  'Confirmed',
#  'Deaths',
#  'Recovered',
#  'Active',
#  'Population',
#  'Unit (all except Population)']

# %% [markdown]
# ## Use Required Columns

# %%
diet_data_subset =diet_data[["Country","Alcoholic Beverages","Animal Products", "Animal fats", "Vegetable Oils","Sugar & Sweeteners",
  "Cereals - Excluding Beer",
  "Vegetal Products",
  "Obesity", "Population"]]

diet_data_subset
# Out:
#                  Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0            Afghanistan               0.0014           9.4341       0.1973
# 1                Albania               1.6719          18.7684       0.1357
# 2                Algeria               0.2711           9.6334       0.0282
# 3                 Angola               5.8087           4.9278       0.0560
# 4    Antigua and Barbuda               3.5764          16.6613       0.0087
# ..                   ...                  ...              ...          ...
# 165            Venezuela               2.5952          14.7565       0.0403
# 166              Vietnam               1.4591           8.5765       0.1640
# 167                Yemen               0.0364           5.7874       0.0446
# 168               Zambia               5.7360           6.0197       0.0829
# 169             Zimbabwe               4.0552           8.1489       0.0755
#
#      Vegetable Oils  Sugar & Sweeteners  Cereals - Excluding Beer  \
# 0            0.5345              1.3489                   24.8097
# 1            0.3261              1.5367                    5.7817
# 2            1.0310              1.8342                   13.6816
# 3            0.6463              1.8495                    9.1085
# 4            0.8102              3.8749                    5.9960
# ..              ...                 ...                       ...
# 165          1.3734              3.4106                   12.9253
# 166          0.2201              1.2846                   16.8740
# 167          1.0811              5.0468                   27.2077
# 168          0.6657              1.5632                   21.1938
# 169          1.7103              4.6485                   22.6240
#
#      Vegetal Products  Obesity  Population
# 0             40.5645      4.5  38928000.0
# 1             31.2304     22.3   2838000.0
# 2             40.3651     26.6  44357000.0
# 3             45.0722      6.8  32522000.0
# 4             33.3233     19.1     98000.0
# ..                ...      ...         ...
# 165           35.2416     25.2  28645000.0
# 166           41.4232      2.1  96209000.0
# 167           44.2126     14.1  29826000.0
# 168           43.9789      6.5  18384000.0
# 169           41.8526     12.3  14863000.0
#
# [170 rows x 10 columns]

# %%
diet_data_subset=diet_data_subset.fillna(0)
diet_data_subset
# Out:
#                  Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0            Afghanistan               0.0014           9.4341       0.1973
# 1                Albania               1.6719          18.7684       0.1357
# 2                Algeria               0.2711           9.6334       0.0282
# 3                 Angola               5.8087           4.9278       0.0560
# 4    Antigua and Barbuda               3.5764          16.6613       0.0087
# ..                   ...                  ...              ...          ...
# 165            Venezuela               2.5952          14.7565       0.0403
# 166              Vietnam               1.4591           8.5765       0.1640
# 167                Yemen               0.0364           5.7874       0.0446
# 168               Zambia               5.7360           6.0197       0.0829
# 169             Zimbabwe               4.0552           8.1489       0.0755
#
#      Vegetable Oils  Sugar & Sweeteners  Cereals - Excluding Beer  \
# 0            0.5345              1.3489                   24.8097
# 1            0.3261              1.5367                    5.7817
# 2            1.0310              1.8342                   13.6816
# 3            0.6463              1.8495                    9.1085
# 4            0.8102              3.8749                    5.9960
# ..              ...                 ...                       ...
# 165          1.3734              3.4106                   12.9253
# 166          0.2201              1.2846                   16.8740
# 167          1.0811              5.0468                   27.2077
# 168          0.6657              1.5632                   21.1938
# 169          1.7103              4.6485                   22.6240
#
#      Vegetal Products  Obesity  Population
# 0             40.5645      4.5  38928000.0
# 1             31.2304     22.3   2838000.0
# 2             40.3651     26.6  44357000.0
# 3             45.0722      6.8  32522000.0
# 4             33.3233     19.1     98000.0
# ..                ...      ...         ...
# 165           35.2416     25.2  28645000.0
# 166           41.4232      2.1  96209000.0
# 167           44.2126     14.1  29826000.0
# 168           43.9789      6.5  18384000.0
# 169           41.8526     12.3  14863000.0
#
# [170 rows x 10 columns]

# %% [markdown]
# ## Analyze the data

# %%
diet_data_subset.describe()
# Out:
#        Alcoholic Beverages  Animal Products  Animal fats  Vegetable Oils  \
# count           170.000000       170.000000   170.000000      170.000000
# mean              3.022971        12.181871     0.221064        0.851554
# std               2.382243         5.852635     0.278304        0.445335
# min               0.000000         1.739100     0.001000        0.091500
# 25%               0.895625         7.236850     0.040225        0.507700
# 50%               2.866150        12.097550     0.116850        0.774450
# 75%               4.710950        16.444125     0.253900        1.070900
# max              15.370600        26.886500     1.355900        2.202600
#
#        Sugar & Sweeteners  Cereals - Excluding Beer  Vegetal Products  \
# count          170.000000                170.000000        170.000000
# mean             2.799115                 11.800347         37.814834
# std              1.545951                  5.824870          5.852943
# min              0.366600                  3.401400         23.113200
# 25%              1.721025                  7.226850         33.552775
# 50%              2.601650                 10.142750         37.900700
# 75%              3.782150                 15.148950         42.762775
# max              9.725900                 29.804500         48.258500
#
#           Obesity    Population
# count  170.000000  1.700000e+02
# mean    18.377647  4.452364e+07
# std      9.862101  1.564182e+08
# min      0.000000  5.400000e+04
# 25%      8.200000  2.816250e+06
# 50%     20.700000  1.018150e+07
# 75%     25.700000  3.271625e+07
# max     45.600000  1.402385e+09

# %% [markdown]
# ## Calculate the STD  Error

# %%
diet_data_subset.sem(axis=0)
# Out:
# Alcoholic Beverages         1.827097e-01
# Animal Products             4.488766e-01
# Animal fats                 2.134498e-02
# Vegetable Oils              3.415567e-02
# Sugar & Sweeteners          1.185690e-01
# Cereals - Excluding Beer    4.467471e-01
# Vegetal Products            4.489002e-01
# Obesity                     7.563886e-01
# Population                  1.199673e+07
# dtype: float64

# %% [markdown]
# ## Load the John Hopkins COVID Confirmed Data

# %%
#Load CSV
confirmed_global="time_series_covid19_confirmed_global.csv"
# Read CSV
confirmed_global_df = pd.read_csv(confirmed_global)

# Show Data
confirmed_global_df
# Out:
#     Province/State         Country/Region        Lat       Long  8/7/2020
# 0              NaN            Afghanistan  33.939110  67.709953     37015
# 1              NaN                Albania  41.153300  20.168300      6151
# 2              NaN                Algeria  28.033900   1.659600     34155
# 3              NaN                Andorra  42.506300   1.521800       955
# 4              NaN                 Angola -11.202700  17.873900      1538
# ..             ...                    ...        ...        ...       ...
# 261            NaN  Sao Tome and Principe   0.186400   6.613100       878
# 262            NaN                  Yemen  15.552727  48.516388      1796
# 263            NaN                Comoros -11.645500  43.333300       396
# 264            NaN             Tajikistan  38.861000  71.276100      7706
# 265            NaN                Lesotho -29.610000  28.233600       742
#
# [266 rows x 5 columns]

# %% [markdown]
# ## Drop the columns  not required

# %%
confirmed_global_df=confirmed_global_df.drop(['Province/State','Lat','Long'], axis=1)
confirmed_global_df
# Out:
#             Country/Region  8/7/2020
# 0              Afghanistan     37015
# 1                  Albania      6151
# 2                  Algeria     34155
# 3                  Andorra       955
# 4                   Angola      1538
# ..                     ...       ...
# 261  Sao Tome and Principe       878
# 262                  Yemen      1796
# 263                Comoros       396
# 264             Tajikistan      7706
# 265                Lesotho       742
#
# [266 rows x 2 columns]

# %% [markdown]
# # Group by Country

# %%
confirmed_global_df=confirmed_global_df.groupby(['Country/Region']).sum().reset_index()
confirmed_global_df
# Out:
#          Country/Region  8/7/2020
# 0           Afghanistan     37015
# 1               Albania      6151
# 2               Algeria     34155
# 3               Andorra       955
# 4                Angola      1538
# ..                  ...       ...
# 182  West Bank and Gaza     13722
# 183      Western Sahara        10
# 184               Yemen      1796
# 185              Zambia      7486
# 186            Zimbabwe      4451
#
# [187 rows x 2 columns]

# %% [markdown]
# ## Load the John Hopkins COVID Deaths Data

# %%
#Load CSV
deaths_global="time_series_covid19_deaths_global.csv"
# Read CSV
deaths_global_df = pd.read_csv(deaths_global)

# Show Data
deaths_global_df
# Out:
#     Province/State         Country/Region        Lat       Long  8/7/2020
# 0              NaN            Afghanistan  33.939110  67.709953      1307
# 1              NaN                Albania  41.153300  20.168300       189
# 2              NaN                Algeria  28.033900   1.659600      1282
# 3              NaN                Andorra  42.506300   1.521800        52
# 4              NaN                 Angola -11.202700  17.873900        67
# ..             ...                    ...        ...        ...       ...
# 261            NaN  Sao Tome and Principe   0.186400   6.613100        15
# 262            NaN                  Yemen  15.552727  48.516388       512
# 263            NaN                Comoros -11.645500  43.333300         7
# 264            NaN             Tajikistan  38.861000  71.276100        62
# 265            NaN                Lesotho -29.610000  28.233600        23
#
# [266 rows x 5 columns]

# %% [markdown]
# ## Drop columns not required

# %%
deaths_global_df=deaths_global_df.drop(['Province/State','Lat','Long'], axis=1)
deaths_global_df
# Out:
#             Country/Region  8/7/2020
# 0              Afghanistan      1307
# 1                  Albania       189
# 2                  Algeria      1282
# 3                  Andorra        52
# 4                   Angola        67
# ..                     ...       ...
# 261  Sao Tome and Principe        15
# 262                  Yemen       512
# 263                Comoros         7
# 264             Tajikistan        62
# 265                Lesotho        23
#
# [266 rows x 2 columns]

# %% [markdown]
# ## Group by Country

# %%
deaths_global_df=deaths_global_df.groupby(['Country/Region']).sum().reset_index()
deaths_global_df
# Out:
#          Country/Region  8/7/2020
# 0           Afghanistan      1307
# 1               Albania       189
# 2               Algeria      1282
# 3               Andorra        52
# 4                Angola        67
# ..                  ...       ...
# 181  West Bank and Gaza        94
# 182      Western Sahara         1
# 183               Yemen       512
# 184              Zambia       200
# 185            Zimbabwe       102
#
# [186 rows x 2 columns]

# %% [markdown]
# ## Merge both the John Hopkins Covid-19 DFs

# %%
#Merge both dataframes
#covid_merged_df= confirmed_global_df.merge(deaths_global_df, on='Country/Region')
covid_merged_df=pd.merge(confirmed_global_df, deaths_global_df, on='Country/Region')
covid_merged_df
# Out:
#          Country/Region  8/7/2020_x  8/7/2020_y
# 0           Afghanistan       37015        1307
# 1               Albania        6151         189
# 2               Algeria       34155        1282
# 3               Andorra         955          52
# 4                Angola        1538          67
# ..                  ...         ...         ...
# 181  West Bank and Gaza       13722          94
# 182      Western Sahara          10           1
# 183               Yemen        1796         512
# 184              Zambia        7486         200
# 185            Zimbabwe        4451         102
#
# [186 rows x 3 columns]

# %% [markdown]
# ## Rename columns appropriately

# %%
covid_merged_df=covid_merged_df.rename({'Country/Region':'Country', '8/7/2020_x':'confirmed','8/7/2020_y':'deaths'}, axis=1)

covid_merged_df
# Out:
#                 Country  confirmed  deaths
# 0           Afghanistan      37015    1307
# 1               Albania       6151     189
# 2               Algeria      34155    1282
# 3               Andorra        955      52
# 4                Angola       1538      67
# ..                  ...        ...     ...
# 181  West Bank and Gaza      13722      94
# 182      Western Sahara         10       1
# 183               Yemen       1796     512
# 184              Zambia       7486     200
# 185            Zimbabwe       4451     102
#
# [186 rows x 3 columns]

# %% [markdown]
# ## Merge the diet data with the COVID-19 data

# %%
diet_covid_merged=diet_data_subset.merge(covid_merged_df, on='Country')
diet_covid_merged
# Out:
#                  Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0            Afghanistan               0.0014           9.4341       0.1973
# 1                Albania               1.6719          18.7684       0.1357
# 2                Algeria               0.2711           9.6334       0.0282
# 3                 Angola               5.8087           4.9278       0.0560
# 4    Antigua and Barbuda               3.5764          16.6613       0.0087
# ..                   ...                  ...              ...          ...
# 154            Venezuela               2.5952          14.7565       0.0403
# 155              Vietnam               1.4591           8.5765       0.1640
# 156                Yemen               0.0364           5.7874       0.0446
# 157               Zambia               5.7360           6.0197       0.0829
# 158             Zimbabwe               4.0552           8.1489       0.0755
#
#      Vegetable Oils  Sugar & Sweeteners  Cereals - Excluding Beer  \
# 0            0.5345              1.3489                   24.8097
# 1            0.3261              1.5367                    5.7817
# 2            1.0310              1.8342                   13.6816
# 3            0.6463              1.8495                    9.1085
# 4            0.8102              3.8749                    5.9960
# ..              ...                 ...                       ...
# 154          1.3734              3.4106                   12.9253
# 155          0.2201              1.2846                   16.8740
# 156          1.0811              5.0468                   27.2077
# 157          0.6657              1.5632                   21.1938
# 158          1.7103              4.6485                   22.6240
#
#      Vegetal Products  Obesity  Population  confirmed  deaths
# 0             40.5645      4.5  38928000.0      37015    1307
# 1             31.2304     22.3   2838000.0       6151     189
# 2             40.3651     26.6  44357000.0      34155    1282
# 3             45.0722      6.8  32522000.0       1538      67
# 4             33.3233     19.1     98000.0         92       3
# ..                ...      ...         ...        ...     ...
# 154           35.2416     25.2  28645000.0      24166     208
# 155           41.4232      2.1  96209000.0        789      10
# 156           44.2126     14.1  29826000.0       1796     512
# 157           43.9789      6.5  18384000.0       7486     200
# 158           41.8526     12.3  14863000.0       4451     102
#
# [159 rows x 12 columns]

# %% [markdown]
# ## Analyze

# %%
diet_covid_merged.describe()
# Out:
#        Alcoholic Beverages  Animal Products  Animal fats  Vegetable Oils  \
# count           159.000000       159.000000   159.000000      159.000000
# mean              3.108328        12.434444     0.226570        0.866842
# std               2.386392         5.868783     0.284018        0.449555
# min               0.000000         1.739100     0.001800        0.091500
# 25%               1.024100         7.597300     0.040250        0.512700
# 50%               3.080500        12.315600     0.120200        0.794900
# 75%               4.734600        16.703950     0.254850        1.101300
# max              15.370600        26.886500     1.355900        2.202600
#
#        Sugar & Sweeteners  Cereals - Excluding Beer  Vegetal Products  \
# count          159.000000                159.000000        159.000000
# mean             2.865632                 11.905891         37.561994
# std              1.549139                  5.892523          5.869055
# min              0.366600                  3.401400         23.113200
# 25%              1.742050                  7.244600         33.285450
# 50%              2.616900                 10.251000         37.683600
# 75%              3.846850                 15.391600         42.398050
# max              9.725900                 29.804500         48.258500
#
#           Obesity    Population     confirmed         deaths
# count  159.000000  1.590000e+02  1.590000e+02     159.000000
# mean    18.403145  4.678216e+07  1.181964e+05    4413.345912
# std      9.340022  1.614024e+08  4.904958e+05   16702.181562
# min      0.000000  5.400000e+04  1.700000e+01       0.000000
# 25%      8.400000  3.321000e+06  1.726000e+03      30.000000
# 50%     21.200000  1.067900e+07  7.923000e+03     189.000000
# 75%     25.700000  3.349900e+07  5.669350e+04    1379.000000
# max     37.300000  1.402385e+09  4.941755e+06  161347.000000

# %%
diet_covid_merged.sem()
# Out:
# Alcoholic Beverages         1.892532e-01
# Animal Products             4.654248e-01
# Animal fats                 2.252406e-02
# Vegetable Oils              3.565200e-02
# Sugar & Sweeteners          1.228547e-01
# Cereals - Excluding Beer    4.673074e-01
# Vegetal Products            4.654464e-01
# Obesity                     7.407119e-01
# Population                  1.280004e+07
# confirmed                   3.889885e+04
# deaths                      1.324569e+03
# dtype: float64

# %% [markdown]
# ## Calculate the Positive Rate

# %%
diet_covid_merged["Positive Test Rate"] = (100 * \
    diet_covid_merged["confirmed"].astype(
        int) / diet_covid_merged["Population"].astype(int)).round(2)
diet_covid_merged
# Out:
#                  Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0            Afghanistan               0.0014           9.4341       0.1973
# 1                Albania               1.6719          18.7684       0.1357
# 2                Algeria               0.2711           9.6334       0.0282
# 3                 Angola               5.8087           4.9278       0.0560
# 4    Antigua and Barbuda               3.5764          16.6613       0.0087
# ..                   ...                  ...              ...          ...
# 154            Venezuela               2.5952          14.7565       0.0403
# 155              Vietnam               1.4591           8.5765       0.1640
# 156                Yemen               0.0364           5.7874       0.0446
# 157               Zambia               5.7360           6.0197       0.0829
# 158             Zimbabwe               4.0552           8.1489       0.0755
#
#      Vegetable Oils  Sugar & Sweeteners  Cereals - Excluding Beer  \
# 0            0.5345              1.3489                   24.8097
# 1            0.3261              1.5367                    5.7817
# 2            1.0310              1.8342                   13.6816
# 3            0.6463              1.8495                    9.1085
# 4            0.8102              3.8749                    5.9960
# ..              ...                 ...                       ...
# 154          1.3734              3.4106                   12.9253
# 155          0.2201              1.2846                   16.8740
# 156          1.0811              5.0468                   27.2077
# 157          0.6657              1.5632                   21.1938
# 158          1.7103              4.6485                   22.6240
#
#      Vegetal Products  Obesity  Population  confirmed  deaths  \
# 0             40.5645      4.5  38928000.0      37015    1307
# 1             31.2304     22.3   2838000.0       6151     189
# 2             40.3651     26.6  44357000.0      34155    1282
# 3             45.0722      6.8  32522000.0       1538      67
# 4             33.3233     19.1     98000.0         92       3
# ..                ...      ...         ...        ...     ...
# 154           35.2416     25.2  28645000.0      24166     208
# 155           41.4232      2.1  96209000.0        789      10
# 156           44.2126     14.1  29826000.0       1796     512
# 157           43.9789      6.5  18384000.0       7486     200
# 158           41.8526     12.3  14863000.0       4451     102
#
#      Positive Test Rate
# 0                  0.10
# 1                  0.22
# 2                  0.08
# 3                  0.00
# 4                  0.09
# ..                  ...
# 154                0.08
# 155                0.00
# 156                0.01
# 157                0.04
# 158                0.03
#
# [159 rows x 13 columns]

# %% [markdown]
# ## Calculate the Death Rate

# %%
diet_covid_merged["Death Rate"] = (100 * \
    diet_covid_merged["deaths"].astype(
        int) / diet_covid_merged["confirmed"].astype(int)).round(2)
diet_covid_merged.head(20)
# Out:
#                    Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0              Afghanistan               0.0014           9.4341       0.1973
# 1                  Albania               1.6719          18.7684       0.1357
# 2                  Algeria               0.2711           9.6334       0.0282
# 3                   Angola               5.8087           4.9278       0.0560
# 4      Antigua and Barbuda               3.5764          16.6613       0.0087
# 5                Argentina               4.2672          19.3454       0.2234
# 6                  Armenia               0.4014          13.5640       0.1833
# 7                Australia               5.5436          21.4175       0.3143
# 8                  Austria               7.0215          19.5654       0.8555
# 9               Azerbaijan               3.5969          11.6416       0.2544
# 10                 Bahamas               2.0175          11.4718       0.0062
# 11              Bangladesh               0.0031           5.1926       0.0156
# 12                Barbados               3.5650          12.4976       0.2212
# 13                 Belarus               3.7563          12.7089       0.3353
# 14                 Belgium               5.3730          17.7279       0.8559
# 15                  Belize               3.3803           8.6856       0.0832
# 16                   Benin               5.9019           3.7504       0.0132
# 17                 Bolivia               2.8956          11.7799       0.0889
# 18  Bosnia and Herzegovina               4.7876          12.4319       0.0585
# 19                Botswana               4.2717          14.4486       0.3402
#
#     Vegetable Oils  Sugar & Sweeteners  Cereals - Excluding Beer  \
# 0           0.5345              1.3489                   24.8097
# 1           0.3261              1.5367                    5.7817
# 2           1.0310              1.8342                   13.6816
# 3           0.6463              1.8495                    9.1085
# 4           0.8102              3.8749                    5.9960
# 5           0.9541              3.0536                    8.4102
# 6           0.4705              2.6579                    7.2982
# 7           1.2798              2.5364                    5.4979
# 8           0.8109              2.6094                    6.2116
# 9           0.2235              1.5523                   13.0898
# 10          0.5110              6.2151                    3.7246
# 11          0.7615              0.9285                   29.8045
# 12          0.8677              4.3344                    8.0666
# 13          0.8804              4.0155                    6.2814
# 14          0.5640              3.6514                    6.6704
# 15          1.0198              3.9798                   11.0700
# 16          0.7381              0.6635                    9.6230
# 17          0.3573              2.5724                   12.3079
# 18          0.4205              1.6391                    8.7152
# 19          1.0065              4.7857                   11.4320
#
#     Vegetal Products  Obesity   Population  confirmed  deaths  \
# 0            40.5645      4.5   38928000.0      37015    1307
# 1            31.2304     22.3    2838000.0       6151     189
# 2            40.3651     26.6   44357000.0      34155    1282
# 3            45.0722      6.8   32522000.0       1538      67
# 4            33.3233     19.1      98000.0         92       3
# 5            30.6559     28.5   45377000.0     235677    4411
# 6            36.4358     20.9    2956000.0      39985     777
# 7            28.5806     30.4   25754000.0      20698     278
# 8            30.4338     21.9    8914000.0      21837     720
# 9            38.3584     19.9   10108000.0      33376     483
# 10           38.5229     32.1     393000.0        830      14
# 11           44.8033      3.4  169809000.0     252502    3333
# 12           37.5167     24.8     287000.0        138       7
# 13           37.2904     26.6    9375000.0      68614     583
# 14           32.2637     24.5   11515000.0      72784    9866
# 15           41.3122     22.4     419000.0        114       2
# 16           46.2493      8.2   12209000.0       1936      38
# 17           38.2165     18.7   11633000.0      87891    3524
# 18           37.5645     19.4    3281000.0      13687     394
# 19           35.5491     16.1    2317000.0        804       2
#
#     Positive Test Rate  Death Rate
# 0                 0.10        3.53
# 1                 0.22        3.07
# 2                 0.08        3.75
# 3                 0.00        4.36
# 4                 0.09        3.26
# 5                 0.52        1.87
# 6                 1.35        1.94
# 7                 0.08        1.34
# 8                 0.24        3.30
# 9                 0.33        1.45
# 10                0.21        1.69
# 11                0.15        1.32
# 12                0.05        5.07
# 13                0.73        0.85
# 14                0.63       13.56
# 15                0.03        1.75
# 16                0.02        1.96
# 17                0.76        4.01
# 18                0.42        2.88
# 19                0.03        0.25

# %% [markdown]
# ## Sort by Death Rate, let us see the top 20

# %%
diet_covid_merged=diet_covid_merged.sort_values(['Death Rate'], ascending=False).reset_index(drop=True)

highest_deaths_rate_data=diet_covid_merged.head(20)
highest_deaths_rate_data
# Out:
#            Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0            Yemen               0.0364           5.7874       0.0446
# 1   United Kingdom               5.2632          18.8798       0.2754
# 2            Italy               3.1892          19.0329       0.2834
# 3          Belgium               5.3730          17.7279       0.8559
# 4          Hungary               6.7533          20.0268       1.0595
# 5           France               4.1631          21.7097       0.7907
# 6           Mexico               4.4105          15.1527       0.1672
# 7      Netherlands               4.3903          24.2977       0.3343
# 8            Spain               5.3152          18.3382       0.2357
# 9             Chad               0.8297          12.2804       0.2023
# 10          Canada               4.8441          16.0365       0.8084
# 11          Sweden               4.4232          24.0627       1.0442
# 12         Ireland               7.5703          18.5712       0.8710
# 13           Sudan               0.0000          13.1178       0.0958
# 14         Ecuador               3.2929          15.3469       0.1277
# 15         Liberia               1.0338           3.7603       0.0264
# 16           Niger               0.0558           7.2385       0.1185
# 17        Slovenia               4.9933          18.9196       1.1248
# 18     Switzerland               4.9978          22.4227       0.4802
# 19           China               2.3224          13.4240       0.0866
#
#     Vegetable Oils  Sugar & Sweeteners  Cereals - Excluding Beer  \
# 0           1.0811              5.0468                   27.2077
# 1           0.7372              2.4383                    6.5412
# 2           1.4224              1.7175                    8.5417
# 3           0.5640              3.6514                    6.6704
# 4           0.7214              2.5433                    7.5908
# 5           0.8675              2.6110                    6.9951
# 6           0.6856              3.2266                   11.4325
# 7           0.8485              2.3446                    4.9685
# 8           1.5122              1.8482                    6.0548
# 9           0.4556              1.3449                   21.6017
# 10          1.3441              5.0237                    6.4236
# 11          0.3967              2.5211                    6.1923
# 12          0.7497              4.0147                    6.3057
# 13          0.9366              3.1231                   12.9192
# 14          1.3777              1.7370                   14.9132
# 15          1.9567              1.1236                   16.1465
# 16          0.3975              0.3666                   22.2843
# 17          0.4739              2.4915                    7.6345
# 18          1.0637              2.9737                    5.9818
# 19          0.5790              3.1065                    8.9298
#
#     Vegetal Products  Obesity    Population  confirmed  deaths  \
# 0            44.2126     14.1  2.982600e+07       1796     512
# 1            31.1116     29.5  6.716000e+07     310696   46596
# 2            30.9671     22.9  6.029600e+07     249756   35190
# 3            32.2637     24.5  1.151500e+07      72784    9866
# 4            29.9644     28.6  9.767000e+06       4621     602
# 5            28.2903     23.2  6.494000e+07     235207   30327
# 6            34.8456     28.4  1.277920e+08     469407   51311
# 7            25.6959     23.1  1.746700e+07      58117    6174
# 8            31.6581     27.1  4.763500e+07     314362   28503
# 9            37.7189      4.8  1.687700e+07        942      76
# 10           33.9551     31.3  3.819000e+07     120903    9017
# 11           25.9282     22.1  1.037700e+07      82323    5763
# 12           31.4242     26.9  5.003000e+06      26470    1772
# 13           36.8813      7.4  4.384900e+07      11894     773
# 14           34.6522     19.3  1.751100e+07      91969    5897
# 15           46.2383      8.6  5.058000e+06       1230      78
# 16           42.7585      4.7  2.418900e+07       1153      69
# 17           31.0774     22.5  2.103000e+06       2233     125
# 18           27.5705     21.2  8.634000e+06      36269    1986
# 19           36.5744      6.6  1.402385e+09      88580    4681
#
#     Positive Test Rate  Death Rate
# 0                 0.01       28.51
# 1                 0.46       15.00
# 2                 0.41       14.09
# 3                 0.63       13.56
# 4                 0.05       13.03
# 5                 0.36       12.89
# 6                 0.37       10.93
# 7                 0.33       10.62
# 8                 0.66        9.07
# 9                 0.01        8.07
# 10                0.32        7.46
# 11                0.79        7.00
# 12                0.53        6.69
# 13                0.03        6.50
# 14                0.53        6.41
# 15                0.02        6.34
# 16                0.00        5.98
# 17                0.11        5.60
# 18                0.42        5.48
# 19                0.01        5.28

# %% [markdown]
# ## Lowest Death rate

# %%
lowest_deaths_rate_data=diet_covid_merged.tail(20)
lowest_deaths_rate_data
# Out:
#                               Country  Alcoholic Beverages  Animal Products  \
# 139                        Uzbekistan               0.6835          14.4463
# 140                              Oman               0.2621          13.5101
# 141                           Namibia               5.4716           9.6094
# 142              United Arab Emirates               0.0000          10.5491
# 143                             Ghana               0.9444           2.8956
# 144                           Iceland               4.7545          23.9700
# 145                            Uganda               6.1671           5.6473
# 146                          Maldives               0.6859          14.2704
# 147                         Sri Lanka               0.6810           5.5328
# 148                             Nepal               0.3318           5.4355
# 149                          Botswana               4.2717          14.4486
# 150                            Rwanda               1.3631           2.6366
# 151                           Grenada               3.1315          12.1319
# 152                       Saint Lucia               7.8024          14.8893
# 153                          Dominica               0.9410           8.9011
# 154  Saint Vincent and the Grenadines               2.5260          11.0865
# 155                       Timor-Leste               0.4459           5.4983
# 156                          Mongolia               3.1430          25.8904
# 157             Saint Kitts and Nevis               4.0867          14.0252
# 158                          Cambodia               4.5783           6.0800
#
#      Animal fats  Vegetable Oils  Sugar & Sweeteners  \
# 139       0.1353          0.6109              0.5796
# 140       0.0571          0.6995              2.5903
# 141       0.1134          0.9531              3.9848
# 142       0.1896          0.7949              3.6576
# 143       0.0088          0.3655              0.8128
# 144       0.9461          0.4667              3.9472
# 145       0.0352          0.7440              1.2601
# 146       0.0029          0.1819              2.9790
# 147       0.0147          0.2466              2.7209
# 148       0.0312          0.8209              0.5470
# 149       0.3402          1.0065              4.7857
# 150       0.0186          0.2109              0.5782
# 151       0.1276          0.9959              5.4480
# 152       0.0252          0.6103              3.7043
# 153       0.0319          0.3797              3.1738
# 154       0.0220          0.7227              3.4592
# 155       0.0897          0.6842              2.8203
# 156       0.3846          0.5550              1.4680
# 157       0.1735          1.3850              6.4623
# 158       0.0377          0.2511              2.9923
#
#      Cereals - Excluding Beer  Vegetal Products  Obesity  Population  \
# 139                   10.5365           35.5540     15.3  34174000.0
# 140                    9.6835           36.4860     22.9   4713000.0
# 141                    9.9189           40.3800     15.0   2541000.0
# 142                   12.9060           39.4461     29.9   9778000.0
# 143                    6.3230           47.1041      9.7  31073000.0
# 144                    4.1196           26.0331     23.1    368000.0
# 145                    6.7480           44.3536      4.1  45741000.0
# 146                   11.5385           35.7208      7.9    541000.0
# 147                   20.7839           44.4618      5.4  21937000.0
# 148                   18.1511           44.5576      3.8  29996000.0
# 149                   11.4320           35.5491     16.1   2317000.0
# 150                    3.5380           47.3634      4.8  12952000.0
# 151                    7.6569           37.8648     20.2    113000.0
# 152                    7.2091           35.0964     19.8    182000.0
# 153                    3.4014           41.0989     28.2     72000.0
# 154                    9.0142           38.9005     23.8    111000.0
# 155                   26.3320           44.5030      2.9   1318000.0
# 156                   10.1415           24.1046     19.6   3361000.0
# 157                    6.3135           35.9677     23.1     54000.0
# 158                   24.8906           43.9195      3.5  15497000.0
#
#      confirmed  deaths  Positive Test Rate  Death Rate
# 139      29057     181                0.09        0.62
# 140      81067     502                1.72        0.62
# 141       2802      16                0.11        0.57
# 142      62061     356                0.63        0.57
# 143      40097     206                0.13        0.51
# 144       1952      10                0.53        0.51
# 145       1254       6                0.00        0.48
# 146       4769      19                0.88        0.40
# 147       2839      11                0.01        0.39
# 148      22214      70                0.07        0.32
# 149        804       2                0.03        0.25
# 150       2128       5                0.02        0.23
# 151         24       0                0.02        0.00
# 152         25       0                0.01        0.00
# 153         18       0                0.02        0.00
# 154         56       0                0.05        0.00
# 155         25       0                0.00        0.00
# 156        293       0                0.01        0.00
# 157         17       0                0.03        0.00
# 158        246       0                0.00        0.00

# %% [markdown]
# ## Comparing some countries, looking for outliers

# %%
diet_covid_merged[diet_covid_merged['Country']== 'Yemen']
# Out:
#   Country  Alcoholic Beverages  Animal Products  Animal fats  Vegetable Oils  \
# 0   Yemen               0.0364           5.7874       0.0446          1.0811
#
#    Sugar & Sweeteners  Cereals - Excluding Beer  Vegetal Products  Obesity  \
# 0              5.0468                   27.2077           44.2126     14.1
#
#    Population  confirmed  deaths  Positive Test Rate  Death Rate
# 0  29826000.0       1796     512                0.01       28.51

# %%
diet_covid_merged[diet_covid_merged['Country']== 'Nepal']
# Out:
#     Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 148   Nepal               0.3318           5.4355       0.0312
#
#      Vegetable Oils  Sugar & Sweeteners  Cereals - Excluding Beer  \
# 148          0.8209               0.547                   18.1511
#
#      Vegetal Products  Obesity  Population  confirmed  deaths  \
# 148           44.5576      3.8  29996000.0      22214      70
#
#      Positive Test Rate  Death Rate
# 148                0.07        0.32

# %%
diet_covid_merged[diet_covid_merged['Country']== 'Japan']
# Out:
#    Country  Alcoholic Beverages  Animal Products  Animal fats  Vegetable Oils  \
# 76   Japan                4.044          15.3194       0.0751          1.3445
#
#     Sugar & Sweeteners  Cereals - Excluding Beer  Vegetal Products  Obesity  \
# 76              2.2055                   12.1692           34.6776      4.4
#
#      Population  confirmed  deaths  Positive Test Rate  Death Rate
# 76  125967000.0      45764    1042                0.04        2.28

# %%
diet_covid_merged[diet_covid_merged['Country']== 'US']
# Out:
#    Country  Alcoholic Beverages  Animal Products  Animal fats  Vegetable Oils  \
# 52      US               4.8647          21.2352       0.1681          0.9889
#
#     Sugar & Sweeteners  Cereals - Excluding Beer  Vegetal Products  Obesity  \
# 52                3.32                    5.5048           28.7587     37.3
#
#      Population  confirmed  deaths  Positive Test Rate  Death Rate
# 52  329878000.0    4941755  161347                 1.5        3.26

# %% [markdown]
# ## Differences in Death Rate can be caused by:
#
# #### Differences in the number of people tested: With more testing, more people with milder cases are identified. This lowers the Death Rate.
# #### Demographics: For example, Mortality tends to be higher in older populations.
# #### Characteristics of the healthcare system: For example, Mortality may rise as hospitals become overwhelmed and have fewer resources.
# #### Other factors, many of which remain unknown.

# %%
used_column_names = [
    'Alcoholic Beverages',
    'Animal Products',
    'Animal fats',
    'Vegetable Oils',
    'Sugar & Sweeteners',
    'Cereals - Excluding Beer',
    'Vegetal Products',
    'Obesity',
    'Population'
]

# %% [markdown]
# ## Computing the average for countries with Hightest/Lowest Death Rates

# %%
highest_deaths_rate_mean = {column_name:highest_deaths_rate_data[column_name].mean() for column_name in used_column_names[:-1]}
print('Average values for records with highest death rate: \n{}'.format(highest_deaths_rate_mean))

lowest_deaths_rate_mean = {column_name:lowest_deaths_rate_data[column_name].mean() for column_name in used_column_names[:-1]}
print('Average values for records with lowest death rate: \n{}'.format(lowest_deaths_rate_mean))
# Out:
# Average values for records with highest death rate:
# {'Alcoholic Beverages': 3.6628749999999997, 'Animal Products': 16.306684999999995, 'Animal fats': 0.45163000000000003, 'Vegetable Oils': 0.908555, 'Sugar & Sweeteners': 2.662705, 'Cereals - Excluding Beer': 10.766765, 'Vegetal Products': 33.689415000000004, 'Obesity': 19.84}
# Average values for records with lowest death rate:
# {'Alcoholic Beverages': 2.613575, 'Animal Products': 11.07272, 'Animal fats': 0.13926499999999997, 'Vegetable Oils': 0.6342649999999999, 'Sugar & Sweeteners': 2.8985700000000003, 'Cereals - Excluding Beer': 11.03191, 'Vegetal Products': 38.923249999999996, 'Obesity': 14.955000000000004}

# %%
diet_covid_merged.to_csv('output2.csv', index = False, header = True)

# %% [markdown]
# # ML approach

# %%
diet_covid_merged.head(20)
# Out:
#            Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0            Yemen               0.0364           5.7874       0.0446
# 1   United Kingdom               5.2632          18.8798       0.2754
# 2            Italy               3.1892          19.0329       0.2834
# 3          Belgium               5.3730          17.7279       0.8559
# 4          Hungary               6.7533          20.0268       1.0595
# 5           France               4.1631          21.7097       0.7907
# 6           Mexico               4.4105          15.1527       0.1672
# 7      Netherlands               4.3903          24.2977       0.3343
# 8            Spain               5.3152          18.3382       0.2357
# 9             Chad               0.8297          12.2804       0.2023
# 10          Canada               4.8441          16.0365       0.8084
# 11          Sweden               4.4232          24.0627       1.0442
# 12         Ireland               7.5703          18.5712       0.8710
# 13           Sudan               0.0000          13.1178       0.0958
# 14         Ecuador               3.2929          15.3469       0.1277
# 15         Liberia               1.0338           3.7603       0.0264
# 16           Niger               0.0558           7.2385       0.1185
# 17        Slovenia               4.9933          18.9196       1.1248
# 18     Switzerland               4.9978          22.4227       0.4802
# 19           China               2.3224          13.4240       0.0866
#
#     Vegetable Oils  Sugar & Sweeteners  Cereals - Excluding Beer  \
# 0           1.0811              5.0468                   27.2077
# 1           0.7372              2.4383                    6.5412
# 2           1.4224              1.7175                    8.5417
# 3           0.5640              3.6514                    6.6704
# 4           0.7214              2.5433                    7.5908
# 5           0.8675              2.6110                    6.9951
# 6           0.6856              3.2266                   11.4325
# 7           0.8485              2.3446                    4.9685
# 8           1.5122              1.8482                    6.0548
# 9           0.4556              1.3449                   21.6017
# 10          1.3441              5.0237                    6.4236
# 11          0.3967              2.5211                    6.1923
# 12          0.7497              4.0147                    6.3057
# 13          0.9366              3.1231                   12.9192
# 14          1.3777              1.7370                   14.9132
# 15          1.9567              1.1236                   16.1465
# 16          0.3975              0.3666                   22.2843
# 17          0.4739              2.4915                    7.6345
# 18          1.0637              2.9737                    5.9818
# 19          0.5790              3.1065                    8.9298
#
#     Vegetal Products  Obesity    Population  confirmed  deaths  \
# 0            44.2126     14.1  2.982600e+07       1796     512
# 1            31.1116     29.5  6.716000e+07     310696   46596
# 2            30.9671     22.9  6.029600e+07     249756   35190
# 3            32.2637     24.5  1.151500e+07      72784    9866
# 4            29.9644     28.6  9.767000e+06       4621     602
# 5            28.2903     23.2  6.494000e+07     235207   30327
# 6            34.8456     28.4  1.277920e+08     469407   51311
# 7            25.6959     23.1  1.746700e+07      58117    6174
# 8            31.6581     27.1  4.763500e+07     314362   28503
# 9            37.7189      4.8  1.687700e+07        942      76
# 10           33.9551     31.3  3.819000e+07     120903    9017
# 11           25.9282     22.1  1.037700e+07      82323    5763
# 12           31.4242     26.9  5.003000e+06      26470    1772
# 13           36.8813      7.4  4.384900e+07      11894     773
# 14           34.6522     19.3  1.751100e+07      91969    5897
# 15           46.2383      8.6  5.058000e+06       1230      78
# 16           42.7585      4.7  2.418900e+07       1153      69
# 17           31.0774     22.5  2.103000e+06       2233     125
# 18           27.5705     21.2  8.634000e+06      36269    1986
# 19           36.5744      6.6  1.402385e+09      88580    4681
#
#     Positive Test Rate  Death Rate
# 0                 0.01       28.51
# 1                 0.46       15.00
# 2                 0.41       14.09
# 3                 0.63       13.56
# 4                 0.05       13.03
# 5                 0.36       12.89
# 6                 0.37       10.93
# 7                 0.33       10.62
# 8                 0.66        9.07
# 9                 0.01        8.07
# 10                0.32        7.46
# 11                0.79        7.00
# 12                0.53        6.69
# 13                0.03        6.50
# 14                0.53        6.41
# 15                0.02        6.34
# 16                0.00        5.98
# 17                0.11        5.60
# 18                0.42        5.48
# 19                0.01        5.28

# %% [markdown]
# ### Check the corelational matrix

# %%
#Removing Yemen from the DF, could be an outlier
diet_covid_merged=diet_covid_merged.drop(diet_covid_merged.index[[0]])


diet_covid_merged.head(20)
# Out:
#            Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 1   United Kingdom               5.2632          18.8798       0.2754
# 2            Italy               3.1892          19.0329       0.2834
# 3          Belgium               5.3730          17.7279       0.8559
# 4          Hungary               6.7533          20.0268       1.0595
# 5           France               4.1631          21.7097       0.7907
# 6           Mexico               4.4105          15.1527       0.1672
# 7      Netherlands               4.3903          24.2977       0.3343
# 8            Spain               5.3152          18.3382       0.2357
# 9             Chad               0.8297          12.2804       0.2023
# 10          Canada               4.8441          16.0365       0.8084
# 11          Sweden               4.4232          24.0627       1.0442
# 12         Ireland               7.5703          18.5712       0.8710
# 13           Sudan               0.0000          13.1178       0.0958
# 14         Ecuador               3.2929          15.3469       0.1277
# 15         Liberia               1.0338           3.7603       0.0264
# 16           Niger               0.0558           7.2385       0.1185
# 17        Slovenia               4.9933          18.9196       1.1248
# 18     Switzerland               4.9978          22.4227       0.4802
# 19           China               2.3224          13.4240       0.0866
# 20           Egypt               0.0722           6.7374       0.0896
#
#     Vegetable Oils  Sugar & Sweeteners  Cereals - Excluding Beer  \
# 1           0.7372              2.4383                    6.5412
# 2           1.4224              1.7175                    8.5417
# 3           0.5640              3.6514                    6.6704
# 4           0.7214              2.5433                    7.5908
# 5           0.8675              2.6110                    6.9951
# 6           0.6856              3.2266                   11.4325
# 7           0.8485              2.3446                    4.9685
# 8           1.5122              1.8482                    6.0548
# 9           0.4556              1.3449                   21.6017
# 10          1.3441              5.0237                    6.4236
# 11          0.3967              2.5211                    6.1923
# 12          0.7497              4.0147                    6.3057
# 13          0.9366              3.1231                   12.9192
# 14          1.3777              1.7370                   14.9132
# 15          1.9567              1.1236                   16.1465
# 16          0.3975              0.3666                   22.2843
# 17          0.4739              2.4915                    7.6345
# 18          1.0637              2.9737                    5.9818
# 19          0.5790              3.1065                    8.9298
# 20          0.3839              1.7984                   17.5311
#
#     Vegetal Products  Obesity    Population  confirmed  deaths  \
# 1            31.1116     29.5  6.716000e+07     310696   46596
# 2            30.9671     22.9  6.029600e+07     249756   35190
# 3            32.2637     24.5  1.151500e+07      72784    9866
# 4            29.9644     28.6  9.767000e+06       4621     602
# 5            28.2903     23.2  6.494000e+07     235207   30327
# 6            34.8456     28.4  1.277920e+08     469407   51311
# 7            25.6959     23.1  1.746700e+07      58117    6174
# 8            31.6581     27.1  4.763500e+07     314362   28503
# 9            37.7189      4.8  1.687700e+07        942      76
# 10           33.9551     31.3  3.819000e+07     120903    9017
# 11           25.9282     22.1  1.037700e+07      82323    5763
# 12           31.4242     26.9  5.003000e+06      26470    1772
# 13           36.8813      7.4  4.384900e+07      11894     773
# 14           34.6522     19.3  1.751100e+07      91969    5897
# 15           46.2383      8.6  5.058000e+06       1230      78
# 16           42.7585      4.7  2.418900e+07       1153      69
# 17           31.0774     22.5  2.103000e+06       2233     125
# 18           27.5705     21.2  8.634000e+06      36269    1986
# 19           36.5744      6.6  1.402385e+09      88580    4681
# 20           43.2622     31.1  1.008030e+08      95147    4971
#
#     Positive Test Rate  Death Rate
# 1                 0.46       15.00
# 2                 0.41       14.09
# 3                 0.63       13.56
# 4                 0.05       13.03
# 5                 0.36       12.89
# 6                 0.37       10.93
# 7                 0.33       10.62
# 8                 0.66        9.07
# 9                 0.01        8.07
# 10                0.32        7.46
# 11                0.79        7.00
# 12                0.53        6.69
# 13                0.03        6.50
# 14                0.53        6.41
# 15                0.02        6.34
# 16                0.00        5.98
# 17                0.11        5.60
# 18                0.42        5.48
# 19                0.01        5.28
# 20                0.09        5.22

# %%
diet_covid_merged.corr()
# Out:
#                           Alcoholic Beverages  Animal Products  Animal fats  \
# Alcoholic Beverages                  1.000000         0.333465     0.447442
# Animal Products                      0.333465         1.000000     0.637216
# Animal fats                          0.447442         0.637216     1.000000
# Vegetable Oils                      -0.118017        -0.086338    -0.140751
# Sugar & Sweeteners                   0.122522         0.259176     0.183164
# Cereals - Excluding Beer            -0.378109        -0.561687    -0.433293
# Vegetal Products                    -0.333537        -1.000000    -0.637125
# Obesity                              0.200264         0.558374     0.384243
# Population                          -0.106588        -0.006712    -0.103180
# confirmed                            0.044160         0.159042    -0.025944
# deaths                               0.097726         0.214748     0.020665
# Positive Test Rate                   0.082790         0.260767     0.069549
# Death Rate                           0.211871         0.321720     0.339534
#
#                           Vegetable Oils  Sugar & Sweeteners  \
# Alcoholic Beverages            -0.118017            0.122522
# Animal Products                -0.086338            0.259176
# Animal fats                    -0.140751            0.183164
# Vegetable Oils                  1.000000            0.174845
# Sugar & Sweeteners              0.174845            1.000000
# Cereals - Excluding Beer        0.199345           -0.195197
# Vegetal Products                0.086234           -0.259294
# Obesity                         0.094581            0.474803
# Population                     -0.053741           -0.085835
# confirmed                       0.054809            0.005824
# deaths                          0.060425           -0.004632
# Positive Test Rate             -0.008862            0.137426
# Death Rate                     -0.016102           -0.075207
#
#                           Cereals - Excluding Beer  Vegetal Products  \
# Alcoholic Beverages                      -0.378109         -0.333537
# Animal Products                          -0.561687         -1.000000
# Animal fats                              -0.433293         -0.637125
# Vegetable Oils                            0.199345          0.086234
# Sugar & Sweeteners                       -0.195197         -0.259294
# Cereals - Excluding Beer                  1.000000          0.561622
# Vegetal Products                          0.561622          1.000000
# Obesity                                  -0.542781         -0.558377
# Population                                0.076261          0.006736
# confirmed                                -0.071781         -0.159027
# deaths                                   -0.124000         -0.214733
# Positive Test Rate                       -0.218076         -0.260774
# Death Rate                               -0.133733         -0.321714
#
#                            Obesity  Population  confirmed    deaths  \
# Alcoholic Beverages       0.200264   -0.106588   0.044160  0.097726
# Animal Products           0.558374   -0.006712   0.159042  0.214748
# Animal fats               0.384243   -0.103180  -0.025944  0.020665
# Vegetable Oils            0.094581   -0.053741   0.054809  0.060425
# Sugar & Sweeteners        0.474803   -0.085835   0.005824 -0.004632
# Cereals - Excluding Beer -0.542781    0.076261  -0.071781 -0.124000
# Vegetal Products         -0.558377    0.006736  -0.159027 -0.214733
# Obesity                   1.000000   -0.184251   0.158262  0.208890
# Population               -0.184251    1.000000   0.402769  0.316214
# confirmed                 0.158262    0.402769   1.000000  0.937381
# deaths                    0.208890    0.316214   0.937381  1.000000
# Positive Test Rate        0.381968   -0.022661   0.396782  0.394605
# Death Rate                0.178600    0.067948   0.069499  0.296619
#
#                           Positive Test Rate  Death Rate
# Alcoholic Beverages                 0.082790    0.211871
# Animal Products                     0.260767    0.321720
# Animal fats                         0.069549    0.339534
# Vegetable Oils                     -0.008862   -0.016102
# Sugar & Sweeteners                  0.137426   -0.075207
# Cereals - Excluding Beer           -0.218076   -0.133733
# Vegetal Products                   -0.260774   -0.321714
# Obesity                             0.381968    0.178600
# Population                         -0.022661    0.067948
# confirmed                           0.396782    0.069499
# deaths                              0.394605    0.296619
# Positive Test Rate                  1.000000    0.062326
# Death Rate                          0.062326    1.000000

# %% [markdown]
# ### Looking at the above corelational matrix, we can see that Animal Products, Obesity,  Alcoholic Beverages and vegetable oils correlate more with deaths.

# %%
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\users\aguha\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\aguha\anaconda3\lib\site-packages (from sklearn) (0.21.3)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in c:\users\aguha\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in c:\users\aguha\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.16.5)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\aguha\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.13.2)

# %%
# Set features. This will also be used as your x values.
X = diet_covid_merged.drop(['deaths', 'Country', 'Population','Death Rate', 'confirmed','Positive Test Rate'], axis=1)

# %%
# Use Deaths for the y values
y=diet_covid_merged["Death Rate"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X
# Out:
#      Alcoholic Beverages  Animal Products  Animal fats  Vegetable Oils  \
# 1                 5.2632          18.8798       0.2754          0.7372
# 2                 3.1892          19.0329       0.2834          1.4224
# 3                 5.3730          17.7279       0.8559          0.5640
# 4                 6.7533          20.0268       1.0595          0.7214
# 5                 4.1631          21.7097       0.7907          0.8675
# ..                   ...              ...          ...             ...
# 154               2.5260          11.0865       0.0220          0.7227
# 155               0.4459           5.4983       0.0897          0.6842
# 156               3.1430          25.8904       0.3846          0.5550
# 157               4.0867          14.0252       0.1735          1.3850
# 158               4.5783           6.0800       0.0377          0.2511
#
#      Sugar & Sweeteners  Cereals - Excluding Beer  Vegetal Products  Obesity
# 1                2.4383                    6.5412           31.1116     29.5
# 2                1.7175                    8.5417           30.9671     22.9
# 3                3.6514                    6.6704           32.2637     24.5
# 4                2.5433                    7.5908           29.9644     28.6
# 5                2.6110                    6.9951           28.2903     23.2
# ..                  ...                       ...               ...      ...
# 154              3.4592                    9.0142           38.9005     23.8
# 155              2.8203                   26.3320           44.5030      2.9
# 156              1.4680                   10.1415           24.1046     19.6
# 157              6.4623                    6.3135           35.9677     23.1
# 158              2.9923                   24.8906           43.9195      3.5
#
# [158 rows x 8 columns]

# %%
y
# Out:
# 1      15.00
# 2      14.09
# 3      13.56
# 4      13.03
# 5      12.89
#        ...
# 154     0.00
# 155     0.00
# 156     0.00
# 157     0.00
# 158     0.00
# Name: Death Rate, Length: 158, dtype: float64

# %% [markdown]
# ## Random Forrest

# %%
from sklearn.ensemble import RandomForestRegressor

#Model
reg = RandomForestRegressor()

#Fit
reg.fit(X, y)
# Out:
# C:\Users\aguha\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
#Score
reg.score(X, y)
# Out:
# 0.7877450651086287

# %%
 [x for x in zip(reg.feature_importances_, X.columns)]
# Out:
# [(0.11217252536551366, 'Alcoholic Beverages'),
#  (0.06644178360826969, 'Animal Products'),
#  (0.2057479388388598, 'Animal fats'),
#  (0.12675653970210526, 'Vegetable Oils'),
#  (0.07575272762109023, 'Sugar & Sweeteners'),
#  (0.15068529978782483, 'Cereals - Excluding Beer'),
#  (0.18822796934711958, 'Vegetal Products'),
#  (0.07421521572921694, 'Obesity')]

# %%
pd.DataFrame([x for x in zip(reg.feature_importances_, X.columns)]).plot(kind='bar', y=0, x=1)

# %% [markdown]
# ### Looking at the feature importances, we can see that Animal fats, Vegetable Oils,  Animal Products seem to have  a high importance in predicting Deaths

# %%
my_df = pd.DataFrame({
    'Alcoholic Beverages':[2.5],
    'Animal Products':[42.5],
    'Animal fats':[22.5],
    'Vegetable Oils':[2.5],
    'Sugar & Sweeteners':[2.5],
    'Cereals - Excluding Beer':[2.5],
    'Vegetal Products':[2.5],
    'Obesity':[32.5]
})

# %%
reg.predict(my_df)
